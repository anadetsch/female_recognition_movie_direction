# %%
import pandas as pd
# import pymysql
# import getpass
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
gender_awards = pd.read_pickle("directors_genders_awards.pkl")

# %%
gender_awards.head(100)
# Out:
#                     director_gender  Winner
# director_name  Year
# Adrian Lyne    1987            male       0
# Akira Kurosawa 1985            male       0
# Alan J. Pakula 1976            male       0
# Alan Parker    1978            male       0
#                1988            male       0
# ...                             ...     ...
# David Lean     1946            male       0
#                1947            male       0
#                1955            male       0
#                1957            male       6
#                1962            male       6
#
# [100 rows x 2 columns]

# %%
gender_awards.plot()

# %%
gender_awards_year = (gender_awards
                      .groupby(["Year"])
                      .agg({"Winner": np.count_nonzero}))

# %%
gender_awards_year.plot()

# %%
gender_awards_new = gender_awards.groupby(["Year", "director_gender"]).agg({"Winner" : "sum"}).reset_index()

# %%
fig, ax = plt.subplots(figsize=(16,9))

sns.lineplot(data = gender_awards_new,
            x = "Year",
            y = "Winner",
            hue = "director_gender");
