# %%
import pandas as pd

# %%
golden_globe_directors = pd.read_csv("golden_globe_df.csv")

# %%
academy_awards= pd.read_csv("academy_award_df.csv")

# %%
directors_all=pd.concat([academy_awards, golden_globe_directors], axis=0)

# %%
directors_all.head(100)
# Out:
#     Year                         Award  Winner  \
# 0   1928    Directing (Comedy Picture)    True
# 1   1928    Directing (Comedy Picture)   False
# 2   1928  Directing (Dramatic Picture)    True
# 3   1928  Directing (Dramatic Picture)   False
# 4   1928  Directing (Dramatic Picture)   False
# ..   ...                           ...     ...
# 95  1948                     Directing   False
# 96  1948                     Directing   False
# 97  1948                     Directing   False
# 98  1948                     Directing    True
# 99  1949                     Directing   False
#
#                                 Film          Nominee           Type Category
# 0                Two Arabian Knights  Lewis Milestone  Academy Award      NaN
# 1                             Speedy        Ted Wilde  Academy Award      NaN
# 2                         7th Heaven    Frank Borzage  Academy Award      NaN
# 3                    Sorrell and Son   Herbert Brenon  Academy Award      NaN
# 4                          The Crowd       King Vidor  Academy Award      NaN
# ..                               ...              ...            ...      ...
# 95                    Johnny Belinda   Jean Negulesco  Academy Award      NaN
# 96                        The Search   Fred Zinnemann  Academy Award      NaN
# 97                     The Snake Pit   Anatole Litvak  Academy Award      NaN
# 98  The Treasure of the Sierra Madre      John Huston  Academy Award      NaN
# 99                All the King's Men    Robert Rossen  Academy Award      NaN
#
# [100 rows x 7 columns]

# %%
directors_all.to_csv("all_directors.csv")

# %%
directors_all["Type"].value_counts()
# Out:
# Academy Award    454
# Golden Globe     358
# Name: Type, dtype: int64

# %%
directors_all=pd.read_excel("awards_all_clean.xlsx")

# %%
directors_all.head()
# Out:
#    Unnamed: 0  Year  Winner                 Film          Nominee  \
# 0           0  1928    True  Two Arabian Knights  Lewis Milestone
# 1           1  1928   False               Speedy        Ted Wilde
# 2           2  1928    True           7th Heaven    Frank Borzage
# 3           3  1928   False      Sorrell and Son   Herbert Brenon
# 4           4  1928   False            The Crowd       King Vidor
#
#             Type
# 0  Academy Award
# 1  Academy Award
# 2  Academy Award
# 3  Academy Award
# 4  Academy Award

# %%
directors_all = directors_all.loc[:, ~directors_all.columns.str.contains('^Unnamed')]

# %%
directors_all.head()
# Out:
#    Year  Winner                 Film          Nominee           Type
# 0  1928    True  Two Arabian Knights  Lewis Milestone  Academy Award
# 1  1928   False               Speedy        Ted Wilde  Academy Award
# 2  1928    True           7th Heaven    Frank Borzage  Academy Award
# 3  1928   False      Sorrell and Son   Herbert Brenon  Academy Award
# 4  1928   False            The Crowd       King Vidor  Academy Award
