# %%
import pandas as pd

# %%
golden_globe = pd.read_csv("golden_globe_awards.csv")

# %%
golden_globe.head(10000)
# Out:
#       year_film  year_award  ceremony  \
# 0          1943        1944         1
# 1          1943        1944         1
# 2          1943        1944         1
# 3          1943        1944         1
# 4          1943        1944         1
# ...         ...         ...       ...
# 7986       2019        2020        77
# 7987       2019        2020        77
# 7988       2019        2020        77
# 7989       2019        2020        77
# 7990       2019        2020        77
#
#                                                category  \
# 0     Best Performance by an Actress in a Supporting...
# 1     Best Performance by an Actor in a Supporting R...
# 2                        Best Director - Motion Picture
# 3                                               Picture
# 4                             Actress In A Leading Role
# ...                                                 ...
# 7986  Best Performance by an Actor in a Supporting R...
# ...

# %%
golden_globe["win"].value_counts()
# Out:
# False    6166
# True     1825
# Name: win, dtype: int64

# %%
golden_globe["ceremony"].value_counts()
# Out:
# 30    150
# 34    141
# 40    137
# 36    132
# 59    131
#      ...
# 6      13
# 4       8
# 3       7
# 1       6
# 2       6
# Name: ceremony, Length: 77, dtype: int64

# %%
golden_globe = golden_globe.drop(columns = "ceremony")

# %%
golden_globe = golden_globe.drop(columns = "year_award")

# %%
golden_globe.head()
# Out:
#    year_film                                           category  \
# 0       1943  Best Performance by an Actress in a Supporting...
# 1       1943  Best Performance by an Actor in a Supporting R...
# 2       1943                     Best Director - Motion Picture
# 3       1943                                            Picture
# 4       1943                          Actress In A Leading Role
#
#                   nominee                     film   win
# 0          Katina Paxinou  For Whom The Bell Tolls  True
# 1           Akim Tamiroff  For Whom The Bell Tolls  True
# 2              Henry King   The Song Of Bernadette  True
# 3  The Song Of Bernadette                      NaN  True
# 4          Jennifer Jones   The Song Of Bernadette  True

# %%
golden_globe = golden_globe.rename(columns = {"year_film" : "Year", "category": "Category", "nominee": "Nominee", "film": "Film", "win": "Winner"})

# %%
golden_globe.head()
# Out:
#    Year                                           Category  \
# 0  1943  Best Performance by an Actress in a Supporting...
# 1  1943  Best Performance by an Actor in a Supporting R...
# 2  1943                     Best Director - Motion Picture
# 3  1943                                            Picture
# 4  1943                          Actress In A Leading Role
#
#                   Nominee                     Film  Winner
# 0          Katina Paxinou  For Whom The Bell Tolls    True
# 1           Akim Tamiroff  For Whom The Bell Tolls    True
# 2              Henry King   The Song Of Bernadette    True
# 3  The Song Of Bernadette                      NaN    True
# 4          Jennifer Jones   The Song Of Bernadette    True

# %%
golden_globe["Film"].isna().sum()
# Out:
# 1800

# %%
((golden_globe["Category"].str.contains("Director")) & (golden_globe["Film"].isna())).sum()
# Out:
# 0

# %%
golden_globe
# Out:
#       Year                                           Category  \
# 0     1943  Best Performance by an Actress in a Supporting...
# 1     1943  Best Performance by an Actor in a Supporting R...
# 2     1943                     Best Director - Motion Picture
# 3     1943                                            Picture
# 4     1943                          Actress In A Leading Role
# ...    ...                                                ...
# 7986  2019  Best Performance by an Actor in a Supporting R...
# 7987  2019  Best Performance by an Actor in a Supporting R...
# 7988  2019  Best Performance by an Actor in a Supporting R...
# 7989  2019                             Cecil B. deMille Award
# 7990  2019                                Carol Burnett Award
#
#                      Nominee                     Film  Winner
# 0             Katina Paxinou  For Whom The Bell Tolls    True
# 1              Akim Tamiroff  For Whom The Bell Tolls    True
# ...

# %%
golden_globe_directors = golden_globe[golden_globe["Category"].str.contains("Director")]

# %%
golden_globe_directors
# Out:
#       Year                        Category            Nominee  \
# 2     1943  Best Director - Motion Picture         Henry King
# 8     1944  Best Director - Motion Picture        Leo McCarey
# 14    1945  Best Director - Motion Picture       Billy Wilder
# 21    1946  Best Director - Motion Picture        Frank Capra
# 29    1947  Best Director - Motion Picture         Elia Kazan
# ...    ...                             ...                ...
# 7904  2019  Best Director - Motion Picture         Sam Mendes
# 7905  2019  Best Director - Motion Picture       Bong Joon Ho
# 7906  2019  Best Director - Motion Picture      Todd Phillips
# 7907  2019  Best Director - Motion Picture    Martin Scorsese
# 7908  2019  Best Director - Motion Picture  Quentin Tarantino
#
#                                  Film  Winner
# 2              The Song Of Bernadette    True
# 8                        Going My Way    True
# 14                   The Lost Weekend    True
# ...

# %%
golden_globe_directors["Category"].str.contains("Director").value_counts()
# Out:
# True    358
# Name: Category, dtype: int64

# %%
golden_globe_directors.insert(loc = 5,column = "Type", value = "Golden Globe")

# %%
golden_globe_directors
# Out:
#       Year                        Category            Nominee  \
# 2     1943  Best Director - Motion Picture         Henry King
# 8     1944  Best Director - Motion Picture        Leo McCarey
# 14    1945  Best Director - Motion Picture       Billy Wilder
# 21    1946  Best Director - Motion Picture        Frank Capra
# 29    1947  Best Director - Motion Picture         Elia Kazan
# ...    ...                             ...                ...
# 7904  2019  Best Director - Motion Picture         Sam Mendes
# 7905  2019  Best Director - Motion Picture       Bong Joon Ho
# 7906  2019  Best Director - Motion Picture      Todd Phillips
# 7907  2019  Best Director - Motion Picture    Martin Scorsese
# 7908  2019  Best Director - Motion Picture  Quentin Tarantino
#
#                                  Film  Winner          Type
# 2              The Song Of Bernadette    True  Golden Globe
# 8                        Going My Way    True  Golden Globe
# ...

# %%
golden_globe_directors.to_csv("golden_globe_df.csv", index = False)
