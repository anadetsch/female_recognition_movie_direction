# %%
import requests
import pandas as pd
import numpy as np
import json
import matplotlib
from pandas import json_normalize

# %%
# Importing TMDB Df_all Pickle 
df_all = pd.read_pickle("df_all2.pkl")

# %%
# Creating df_all slice
df_clean = df_all[["director_name","director_gender","director_id", "director_popularity", "movie_release_date","movie_vote_average","movie_vote_count","movie_original_language","movie_title","movie_id","director_known_for_department"]]
df_clean.head(4)
# Out:
#     director_name director_gender director_id director_popularity  \
# 0  Dodo Abashidze               2      560142               0.728
# 1  Dodo Abashidze               2      560142               0.728
# 2  Dodo Abashidze               2      560142               0.728
# 3   George Abbott               2        2004                 0.6
#
#   movie_release_date  movie_vote_average  movie_vote_count  \
# 0         1985-12-01                 7.1              14.0
# 1         1968-12-22                 5.8              12.0
# 2         1969-12-28                 6.1              11.0
# 3         1957-08-29                 6.3              21.0
#
#   movie_original_language                   movie_title  movie_id  \
# 0                      ka  The Legend of Suram Fortress  103590.0
# 1                      ka                 Don't Grieve!   27922.0
# 2                      ka                     Pirosmani   88302.0
# 3                      en               The Pajama Game   40867.0
#
#   director_known_for_department
# 0                        Acting
# 1                        Acting
# 2                        Acting
# 3                     Directing

# %%
# Checking Value Counts for names

df_clean["director_name"].value_counts()
# Out:
# James Young            31
# Colin Campbell         26
# John Gilbert           25
# John Hughes            23
# Michael Moore          23
#                        ..
# David Walling           1
# Paula Verhoeven         1
# William Howard Taft     1
# Sam B. Wood             1
# Prince Charming         1
# Name: director_name, Length: 3103, dtype: int64

# %%
# Removing non writers, directors

#1. Check value counts for known fors:

df_clean["director_known_for_department"].value_counts()
# Out:
# Directing            4638
# Acting               2540
# Writing               845
# Production            430
# Sound                 184
# Camera                143
# Editing               105
# Art                    95
# Crew                   90
# Visual Effects         51
# Costume & Make-Up      50
# Lighting               21
# Creator                11
# Name: director_known_for_department, dtype: int64

# %%
# Keep in new df: ["Directing", "Writing", "Production"]

df_clean_dir = df_clean[df_clean["director_known_for_department"].isin(["Directing","Writing","Production"])]
df_clean_dir
# Out:
#             director_name director_gender director_id director_popularity  \
# 3           George Abbott               2        2004                 0.6
# 4           George Abbott               2        2004                 0.6
# 5           George Abbott               2        2004                 0.6
# 6     George Abbott Clark               0     1811971                 0.6
# 7            Jim Abrahams               2       12936               1.456
# ...                   ...             ...         ...                 ...
# 9198     Andrzej Żuławski               2       32082                 0.6
# 9199     Andrzej Żuławski               2       32082                 0.6
# 9200      Xawery Żuławski               2     1138544                 0.6
# 9201      Xawery Żuławski               2     1138544                 0.6
# 9202      Xawery Żuławski               2     1138544                 0.6
#
#      movie_release_date  movie_vote_average  movie_vote_count  \
# 3            1957-08-29                 6.3              21.0
# 4            1958-07-23                 6.9              17.0
# 5            1931-11-28                 6.3               9.0
# 6            2017-05-02                 4.9              84.0
# 7            1980-07-02                 7.3            2453.0
# ...                 ...                 ...               ...
# 9198         1988-10-09                 8.3              46.0
# 9199         1975-02-12                 7.5              43.0
# 9200         2009-04-21                 5.7              30.0
# 9201                NaN                 8.0               7.0
# 9202         2006-07-22                 5.3               3.0
#
#      movie_original_language                      movie_title  movie_id  \
# 3                         en                  The Pajama Game   40867.0
# 4                         en                    Damn Yankees!   41253.0
# 5                         en                        The Cheat  156324.0
# 6                         en                The Shadow Effect  383538.0
# 7                         en                        Airplane!     813.0
# ...                      ...                              ...       ...
# 9198                      pl              On the Silver Globe   27072.0
# 9199                      fr  That Most Important Thing: Love    3476.0
# 9200                      pl       Snow White and Russian Red   36415.0
# 9201                      pl                              NaN   37337.0
# 9202                      pl                            Chaos  155675.0
#
#      director_known_for_department
# 3                        Directing
# 4                        Directing
# 5                        Directing
# 6                          Writing
# 7                          Writing
# ...                            ...
# 9198                       Writing
# 9199                       Writing
# 9200                     Directing
# 9201                     Directing
# 9202                     Directing
#
# [5913 rows x 11 columns]

# %%
# Checking again name value counts
df_clean_dir["director_name"].value_counts()
# Out:
# Frank Miller         12
# David Howard         12
# John Rice             9
# John Hughes           9
# Paul McGuigan         9
#                      ..
# Randall Kirk          1
# Andre van Heerden     1
# John Landis           1
# Michael J. Mann       1
# Randal Kirk II        1
# Name: director_name, Length: 2047, dtype: int64

# %%
# Removing duplicates

df_clean_dir_dupes = df_clean_dir.drop_duplicates(["director_id", "movie_id"], ignore_index=True)
df_clean_dir_dupes["director_name"].value_counts()
# Out:
# David Howard           12
# Frank Miller           12
# John Hughes             9
# Paul McGuigan           9
# John Rice               9
#                        ..
# David W. Siegel         1
# Harry Joe Brown Jr.     1
# Yang Li                 1
# David Wallach           1
# Robert Wiener           1
# Name: director_name, Length: 2047, dtype: int64

# %%
# Check David Howard
df_clean_dir_dupes.loc[df_clean_dir_dupes["director_name"].str.contains("David Howard")]
# Out:
#          director_name director_gender director_id director_popularity  \
# 2328      David Howard               2       15003                 0.6
# 2329      David Howard               2       15003                 0.6
# 2330      David Howard               2       15003                 0.6
# 2331      David Howard               0     1138030                 0.6
# 2332      David Howard               0     1138030                 0.6
# 2333      David Howard               0     1138030                 0.6
# 2334      David Howard               0     2247270                 0.6
# 2335      David Howard               0     1118819                 0.6
# 2336      David Howard               0     1118819                 0.6
# 2337      David Howard               0     1030519                 0.6
# 2338      David Howard               0     1030519                 0.6
# 2339      David Howard               0     1030519                 0.6
# 2340  David Howard Lee               0     2371444                 0.6
#
#      movie_release_date  movie_vote_average  movie_vote_count  \
# 2328         1999-12-23                 7.0            1275.0
# 2329         2007-11-07                 6.1              37.0
# 2330         1995-09-30                 6.9              13.0
# 2331         2008-10-03                 5.0               3.0
# 2332         2016-06-12                 6.0               1.0
# 2333         1932-12-30                 0.0               0.0
# 2334         1933-01-01                 0.0               0.0
# 2335         2012-11-23                 6.2               5.0
# 2336         2000-04-16                 5.0               3.0
# 2337         1936-10-16                 4.2               6.0
# 2338         1938-09-16                 5.0               4.0
# 2339         1931-12-03                 6.7               3.0
# 2340                NaN                 5.5               2.0
#
#      movie_original_language  \
# 2328                      en
# 2329                      en
# 2330                      de
# 2331                      en
# 2332                      en
# 2333                      en
# 2334                      en
# 2335                      es
# 2336                      en
# 2337                      en
# 2338                      en
# 2339                      es
# 2340                      en
#
#                                             movie_title  movie_id  \
# 2328                                       Galaxy Quest     926.0
# 2329  The Three Investigators and The Secret Of Skel...    4407.0
# 2330                  After Five In The Forest Primeval    4285.0
# 2331                                              Flick   26772.0
# 2332                          Interview With A Murderer  402267.0
# 2333                                     Robbers' Roost  523280.0
# 2334                                    Smoke Lightning  434729.0
# 2335                                        Hidden Moon  143311.0
# 2336                                         The Hustle  166641.0
# 2337                                       Daniel Boone  102379.0
# 2338                                The Renegade Ranger  146505.0
# 2339                                         Eran trece  156325.0
# 2340                                                NaN   90834.0
#
#      director_known_for_department
# 2328                       Writing
# 2329                       Writing
# 2330                       Writing
# 2331                     Directing
# 2332                     Directing
# 2333                     Directing
# 2334                     Directing
# 2335                       Writing
# 2336                       Writing
# 2337                     Directing
# 2338                     Directing
# 2339                     Directing
# 2340                       Writing

# %%
# There are multiple David Howards, who are Directors or Writers - WE KEEP THEM, because there are multipl of them fitting criteria

# Now we check for Genders and clean that
df_clean_dir_dupes["director_gender"].value_counts()
# Out:
# 2    4342
# 0    1254
# 1     281
# Name: director_gender, dtype: int64

# %%
# First we remove all rows with a zero Gender

df_clean_dir_dupes_nozero = df_clean_dir_dupes.drop(df_clean_dir_dupes[df_clean_dir_dupes["director_gender"]==0].index)
df_clean_dir_dupes_nozero
# Out:
#          director_name director_gender director_id director_popularity  \
# 0        George Abbott               2        2004                 0.6
# 1        George Abbott               2        2004                 0.6
# 2        George Abbott               2        2004                 0.6
# 4         Jim Abrahams               2       12936               1.456
# 5         Jim Abrahams               2       12936               1.456
# ...                ...             ...         ...                 ...
# 5872  Andrzej Żuławski               2       32082                 0.6
# 5873  Andrzej Żuławski               2       32082                 0.6
# 5874   Xawery Żuławski               2     1138544                 0.6
# 5875   Xawery Żuławski               2     1138544                 0.6
# 5876   Xawery Żuławski               2     1138544                 0.6
#
#      movie_release_date  movie_vote_average  movie_vote_count  \
# 0            1957-08-29                 6.3              21.0
# 1            1958-07-23                 6.9              17.0
# 2            1931-11-28                 6.3               9.0
# 4            1980-07-02                 7.3            2453.0
# 5            1988-12-02                 7.2            2089.0
# ...                 ...                 ...               ...
# 5872         1988-10-09                 8.3              46.0
# 5873         1975-02-12                 7.5              43.0
# 5874         2009-04-21                 5.7              30.0
# 5875                NaN                 8.0               7.0
# 5876         2006-07-22                 5.3               3.0
#
#      movie_original_language                                     movie_title  \
# 0                         en                                 The Pajama Game
# 1                         en                                   Damn Yankees!
# 2                         en                                       The Cheat
# 4                         en                                       Airplane!
# 5                         en  The Naked Gun: From the Files of Police Squad!
# ...                      ...                                             ...
# 5872                      pl                             On the Silver Globe
# 5873                      fr                 That Most Important Thing: Love
# 5874                      pl                      Snow White and Russian Red
# 5875                      pl                                             NaN
# 5876                      pl                                           Chaos
#
#       movie_id director_known_for_department
# 0      40867.0                     Directing
# 1      41253.0                     Directing
# 2     156324.0                     Directing
# 4        813.0                       Writing
# 5      37136.0                       Writing
# ...        ...                           ...
# 5872   27072.0                       Writing
# 5873    3476.0                       Writing
# 5874   36415.0                     Directing
# 5875   37337.0                     Directing
# 5876  155675.0                     Directing
#
# [4623 rows x 11 columns]

# %%
# Changing one and two to female and male, respectively

df_clean_dir_dupes_gendername = df_clean_dir_dupes_nozero.assign(director_gender=np.where(df_clean_dir_dupes_nozero["director_gender"]==2,"male","female"))
df_clean_dir_dupes_gendername.head(5)
# Out:
#    director_name director_gender director_id director_popularity  \
# 0  George Abbott            male        2004                 0.6
# 1  George Abbott            male        2004                 0.6
# 2  George Abbott            male        2004                 0.6
# 4   Jim Abrahams            male       12936               1.456
# 5   Jim Abrahams            male       12936               1.456
#
#   movie_release_date  movie_vote_average  movie_vote_count  \
# 0         1957-08-29                 6.3              21.0
# 1         1958-07-23                 6.9              17.0
# 2         1931-11-28                 6.3               9.0
# 4         1980-07-02                 7.3            2453.0
# 5         1988-12-02                 7.2            2089.0
#
#   movie_original_language                                     movie_title  \
# 0                      en                                 The Pajama Game
# 1                      en                                   Damn Yankees!
# 2                      en                                       The Cheat
# 4                      en                                       Airplane!
# 5                      en  The Naked Gun: From the Files of Police Squad!
#
#    movie_id director_known_for_department
# 0   40867.0                     Directing
# 1   41253.0                     Directing
# 2  156324.0                     Directing
# 4     813.0                       Writing
# 5   37136.0                       Writing

# %%
# Make the movie_release_date to move_release_year

df_clean_dir_dupes_gendername_year = df_clean_dir_dupes_gendername.assign(movie_year=(pd.to_datetime(df_clean_dir_dupes_gendername["movie_release_date"].str.slice(stop=-6))))
df_clean_dir_dupes_gendername_year[["movie_year"]].describe().transpose()
# Out:
#            count unique        top freq      first       last
# movie_year  4309    120 2013-01-01   99 1887-01-01 2021-01-01

# %%
df_clean_dir_dupes_gendername_year
# Out:
#          director_name director_gender director_id director_popularity  \
# 0        George Abbott            male        2004                 0.6
# 1        George Abbott            male        2004                 0.6
# 2        George Abbott            male        2004                 0.6
# 4         Jim Abrahams            male       12936               1.456
# 5         Jim Abrahams            male       12936               1.456
# ...                ...             ...         ...                 ...
# 5872  Andrzej Żuławski            male       32082                 0.6
# 5873  Andrzej Żuławski            male       32082                 0.6
# 5874   Xawery Żuławski            male     1138544                 0.6
# 5875   Xawery Żuławski            male     1138544                 0.6
# 5876   Xawery Żuławski            male     1138544                 0.6
#
#      movie_release_date  movie_vote_average  movie_vote_count  \
# 0            1957-08-29                 6.3              21.0
# 1            1958-07-23                 6.9              17.0
# 2            1931-11-28                 6.3               9.0
# 4            1980-07-02                 7.3            2453.0
# 5            1988-12-02                 7.2            2089.0
# ...                 ...                 ...               ...
# 5872         1988-10-09                 8.3              46.0
# 5873         1975-02-12                 7.5              43.0
# 5874         2009-04-21                 5.7              30.0
# 5875                NaN                 8.0               7.0
# 5876         2006-07-22                 5.3               3.0
#
#      movie_original_language                                     movie_title  \
# 0                         en                                 The Pajama Game
# 1                         en                                   Damn Yankees!
# 2                         en                                       The Cheat
# 4                         en                                       Airplane!
# 5                         en  The Naked Gun: From the Files of Police Squad!
# ...                      ...                                             ...
# 5872                      pl                             On the Silver Globe
# 5873                      fr                 That Most Important Thing: Love
# 5874                      pl                      Snow White and Russian Red
# 5875                      pl                                             NaN
# 5876                      pl                                           Chaos
#
#       movie_id director_known_for_department movie_year
# 0      40867.0                     Directing 1957-01-01
# 1      41253.0                     Directing 1958-01-01
# 2     156324.0                     Directing 1931-01-01
# 4        813.0                       Writing 1980-01-01
# 5      37136.0                       Writing 1988-01-01
# ...        ...                           ...        ...
# 5872   27072.0                       Writing 1988-01-01
# 5873    3476.0                       Writing 1975-01-01
# 5874   36415.0                     Directing 2009-01-01
# 5875   37337.0                     Directing        NaT
# 5876  155675.0                     Directing 2006-01-01
#
# [4623 rows x 12 columns]

# %%
# Rename most current DF and pickle:
df_tmdb = df_clean_dir_dupes_gendername_year.copy()
#df_tmdb.to_pickle("df_tmdb.pkl")

# %%
#2. Merging the Awardsdf to df_tmdb ON Film Names
#1 Getting pickle of all director awards
df_awards = pd.read_pickle("directors_all.pkl")
df_awards
# Out:
#      Year  Winner                             Film            Nominee  \
# 0    1928    True              Two Arabian Knights    Lewis Milestone
# 1    1928   False                           Speedy          Ted Wilde
# 2    1928    True                       7th Heaven      Frank Borzage
# 3    1928   False                  Sorrell and Son     Herbert Brenon
# 4    1928   False                        The Crowd         King Vidor
# ..    ...     ...                              ...                ...
# 807  2019    True                             1917         Sam Mendes
# 808  2019   False                         Parasite       Bong Joon Ho
# 809  2019   False                            Joker      Todd Phillips
# 810  2019   False                    Irishman, The    Martin Scorsese
# 811  2019   False  Once Upon a Time...in Hollywood  Quentin Tarantino
#
#               Type
# 0    Academy Award
# 1    Academy Award
# 2    Academy Award
# 3    Academy Award
# 4    Academy Award
# ..             ...
# 807   Golden Globe
# 808   Golden Globe
# 809   Golden Globe
# 810   Golden Globe
# 811   Golden Globe
#
# [812 rows x 5 columns]

# %%
# Merging on Awards
df_tmdb_awards = df_tmdb.merge(df_awards, how = "left", left_on = "movie_title", right_on = "Film")
df_tmdb_awards["Film"].value_counts()
# Out:
# Titanic                                              6
# Apocalypse Now                                       4
# War and Peace                                        4
# The Lord of the Rings: The Fellowship of the Ring    4
# Pulp Fiction                                         4
#                                                     ..
# Captain Phillips                                     1
# The Broadway Melody                                  1
# The Front Page                                       1
# The Emigrants                                        1
# Star Wars                                            1
# Name: Film, Length: 256, dtype: int64

# %%
# Checking Why more rows in new tmdb_awards DF:
df_tmdb.loc[df_tmdb["movie_title"].isin(["Titanic"])]
# Out:
#        director_name director_gender director_id director_popularity  \
# 757    James Cameron            male        2710               1.426
# 3747  Jean Negulesco            male       19606               0.982
# 4704  Herbert Selpin            male       67840                 0.6
#
#      movie_release_date  movie_vote_average  movie_vote_count  \
# 757          1997-11-18                 7.8           16444.0
# 3747         1953-04-11                 6.4              55.0
# 4704         1943-11-10                 6.2              33.0
#
#      movie_original_language movie_title  movie_id  \
# 757                       en     Titanic     597.0
# 3747                      en     Titanic   16535.0
# 4704                      de     Titanic   11021.0
#
#      director_known_for_department movie_year
# 757                      Directing 1997-01-01
# 3747                     Directing 1953-01-01
# 4704                     Directing 1943-01-01

# %%
# Checking Why more rows in new tmdb_awards DF: 
# Because multiple award types for several movies

df_tmdb_awards.loc[df_tmdb_awards["movie_title"].isin(["Titanic"])]
# Out:
#        director_name director_gender director_id director_popularity  \
# 662    James Cameron            male        2710               1.426
# 663    James Cameron            male        2710               1.426
# 3030  Jean Negulesco            male       19606               0.982
# 3031  Jean Negulesco            male       19606               0.982
# 3796  Herbert Selpin            male       67840                 0.6
# 3797  Herbert Selpin            male       67840                 0.6
#
#      movie_release_date  movie_vote_average  movie_vote_count  \
# 662          1997-11-18                 7.8           16444.0
# 663          1997-11-18                 7.8           16444.0
# 3030         1953-04-11                 6.4              55.0
# 3031         1953-04-11                 6.4              55.0
# 3796         1943-11-10                 6.2              33.0
# 3797         1943-11-10                 6.2              33.0
#
#      movie_original_language movie_title  movie_id  \
# 662                       en     Titanic     597.0
# 663                       en     Titanic     597.0
# 3030                      en     Titanic   16535.0
# 3031                      en     Titanic   16535.0
# 3796                      de     Titanic   11021.0
# 3797                      de     Titanic   11021.0
#
#      director_known_for_department movie_year    Year Winner     Film  \
# 662                      Directing 1997-01-01  1997.0   True  Titanic
# 663                      Directing 1997-01-01  1997.0   True  Titanic
# 3030                     Directing 1953-01-01  1997.0   True  Titanic
# 3031                     Directing 1953-01-01  1997.0   True  Titanic
# 3796                     Directing 1943-01-01  1997.0   True  Titanic
# 3797                     Directing 1943-01-01  1997.0   True  Titanic
#
#             Nominee           Type
# 662   James Cameron  Academy Award
# 663   James Cameron   Golden Globe
# 3030  James Cameron  Academy Award
# 3031  James Cameron   Golden Globe
# 3796  James Cameron  Academy Award
# 3797  James Cameron   Golden Globe

# %%
df_tmdb_awards.to_pickle("df_tmdb_awards.pkl")

# %%
df_tmdb_awards
# Out:
#          director_name director_gender director_id director_popularity  \
# 0        George Abbott            male        2004                 0.6
# 1        George Abbott            male        2004                 0.6
# 2        George Abbott            male        2004                 0.6
# 3         Jim Abrahams            male       12936               1.456
# 4         Jim Abrahams            male       12936               1.456
# ...                ...             ...         ...                 ...
# 4714  Andrzej Żuławski            male       32082                 0.6
# 4715  Andrzej Żuławski            male       32082                 0.6
# 4716   Xawery Żuławski            male     1138544                 0.6
# 4717   Xawery Żuławski            male     1138544                 0.6
# 4718   Xawery Żuławski            male     1138544                 0.6
#
#      movie_release_date  movie_vote_average  movie_vote_count  \
# 0            1957-08-29                 6.3              21.0
# 1            1958-07-23                 6.9              17.0
# 2            1931-11-28                 6.3               9.0
# 3            1980-07-02                 7.3            2453.0
# 4            1988-12-02                 7.2            2089.0
# ...                 ...                 ...               ...
# 4714         1988-10-09                 8.3              46.0
# 4715         1975-02-12                 7.5              43.0
# 4716         2009-04-21                 5.7              30.0
# 4717                NaN                 8.0               7.0
# 4718         2006-07-22                 5.3               3.0
#
#      movie_original_language                                     movie_title  \
# 0                         en                                 The Pajama Game
# 1                         en                                   Damn Yankees!
# 2                         en                                       The Cheat
# 3                         en                                       Airplane!
# 4                         en  The Naked Gun: From the Files of Police Squad!
# ...                      ...                                             ...
# 4714                      pl                             On the Silver Globe
# 4715                      fr                 That Most Important Thing: Love
# 4716                      pl                      Snow White and Russian Red
# 4717                      pl                                             NaN
# 4718                      pl                                           Chaos
#
#       movie_id director_known_for_department movie_year  Year Winner Film  \
# 0      40867.0                     Directing 1957-01-01   NaN    NaN  NaN
# 1      41253.0                     Directing 1958-01-01   NaN    NaN  NaN
# 2     156324.0                     Directing 1931-01-01   NaN    NaN  NaN
# 3        813.0                       Writing 1980-01-01   NaN    NaN  NaN
# 4      37136.0                       Writing 1988-01-01   NaN    NaN  NaN
# ...        ...                           ...        ...   ...    ...  ...
# 4714   27072.0                       Writing 1988-01-01   NaN    NaN  NaN
# 4715    3476.0                       Writing 1975-01-01   NaN    NaN  NaN
# 4716   36415.0                     Directing 2009-01-01   NaN    NaN  NaN
# 4717   37337.0                     Directing        NaT   NaN    NaN  NaN
# 4718  155675.0                     Directing 2006-01-01   NaN    NaN  NaN
#
#      Nominee Type
# 0        NaN  NaN
# 1        NaN  NaN
# 2        NaN  NaN
# 3        NaN  NaN
# 4        NaN  NaN
# ...      ...  ...
# 4714     NaN  NaN
# 4715     NaN  NaN
# 4716     NaN  NaN
# 4717     NaN  NaN
# 4718     NaN  NaN
#
# [4719 rows x 17 columns]

# %%
# Remove Nan for winner
# Show populrity and gender for Winner/Nominee - groupby gender, winnertype / agg. director popularity mean

# %%
# Remove NaN for winner df.dropna(subset=['name', 'born'])


df_tmdb_awards_nona = df_tmdb_awards.dropna(subset=["Winner"])
df_tmdb_awards_nona
# Out:
#        director_name director_gender director_id director_popularity  \
# 84       Woody Allen            male        1243               4.288
# 85       Woody Allen            male        1243               4.288
# 86       Woody Allen            male        1243               4.288
# 87       Woody Allen            male        1243               4.288
# 94     Robert Altman            male        9789               1.603
# ...              ...             ...         ...                 ...
# 4699  Fred Zinnemann            male        4065                0.84
# 4700  Fred Zinnemann            male        4065                0.84
# 4701  Fred Zinnemann            male        4065                0.84
# 4707     Erick Zonca            male       19377                 0.6
# 4708     Erick Zonca            male       19377                 0.6
#
#      movie_release_date  movie_vote_average  movie_vote_count  \
# 84           2011-05-11                 7.5            4670.0
# 85           2005-10-26                 7.3            2560.0
# 86           1977-04-19                 7.8            2399.0
# 87           1977-04-19                 7.8            2399.0
# 94           2001-11-07                 7.0             561.0
# ...                 ...                 ...               ...
# 4699         1952-06-09                 7.7             751.0
# 4700         1953-08-28                 7.4             299.0
# 4701         1953-08-28                 7.4             299.0
# 4707         2008-02-09                 7.1              45.0
# 4708         2008-02-09                 7.1              45.0
#
#      movie_original_language            movie_title  movie_id  \
# 84                        en      Midnight in Paris   59436.0
# 85                        en            Match Point     116.0
# 86                        en             Annie Hall     703.0
# 87                        en             Annie Hall     703.0
# 94                        en           Gosford Park    5279.0
# ...                      ...                    ...       ...
# 4699                      en              High Noon     288.0
# 4700                      en  From Here to Eternity   11426.0
# 4701                      en  From Here to Eternity   11426.0
# 4707                      en                  Julia    7351.0
# 4708                      en                  Julia    7351.0
#
#      director_known_for_department movie_year    Year Winner  \
# 84                       Directing 2011-01-01  2011.0  False
# 85                       Directing 2005-01-01  2005.0  False
# 86                       Directing 1977-01-01  1977.0   True
# 87                       Directing 1977-01-01  1977.0  False
# 94                       Directing 2001-01-01  2001.0  False
# ...                            ...        ...     ...    ...
# 4699                     Directing 1952-01-01  1952.0  False
# 4700                     Directing 1953-01-01  1953.0   True
# 4701                     Directing 1953-01-01  1953.0   True
# 4707                       Writing 2008-01-01  1977.0  False
# 4708                       Writing 2008-01-01  1977.0  False
#
#                        Film         Nominee           Type
# 84        Midnight in Paris     Woody Allen  Academy Award
# 85              Match Point     Woody Allen   Golden Globe
# 86               Annie Hall     Woody Allen  Academy Award
# 87               Annie Hall     Woody Allen   Golden Globe
# 94             Gosford Park   Robert Altman  Academy Award
# ...                     ...             ...            ...
# 4699              High Noon  Fred Zinnemann  Academy Award
# 4700  From Here to Eternity  Fred Zinnemann  Academy Award
# 4701  From Here to Eternity  Fred Zinnemann   Golden Globe
# 4707                  Julia  Fred Zinnemann  Academy Award
# 4708                  Julia  Fred Zinnemann   Golden Globe
#
# [385 rows x 17 columns]

# %%
# Make to "mean" columns as dtype float64: df.astype({'col1': 'float64'}).dtypes
df_tmdb_awards_nona = df_tmdb_awards_nona.astype({"director_popularity":"float64", "movie_vote_average" : "float64"})

# %%
df_tmdb_awards_nona = df_tmdb_awards_nona.assign(director_gender=np.where(df_tmdb_awards_nona["director_gender"]=="male",2,1))

df_tmdb_awards_nona
# Out:
#        director_name  director_gender director_id  director_popularity  \
# 84       Woody Allen                2        1243                4.288
# 85       Woody Allen                2        1243                4.288
# 86       Woody Allen                2        1243                4.288
# 87       Woody Allen                2        1243                4.288
# 94     Robert Altman                2        9789                1.603
# ...              ...              ...         ...                  ...
# 4699  Fred Zinnemann                2        4065                0.840
# 4700  Fred Zinnemann                2        4065                0.840
# 4701  Fred Zinnemann                2        4065                0.840
# 4707     Erick Zonca                2       19377                0.600
# 4708     Erick Zonca                2       19377                0.600
#
#      movie_release_date  movie_vote_average  movie_vote_count  \
# 84           2011-05-11                 7.5            4670.0
# 85           2005-10-26                 7.3            2560.0
# 86           1977-04-19                 7.8            2399.0
# 87           1977-04-19                 7.8            2399.0
# 94           2001-11-07                 7.0             561.0
# ...                 ...                 ...               ...
# 4699         1952-06-09                 7.7             751.0
# 4700         1953-08-28                 7.4             299.0
# 4701         1953-08-28                 7.4             299.0
# 4707         2008-02-09                 7.1              45.0
# 4708         2008-02-09                 7.1              45.0
#
#      movie_original_language            movie_title  movie_id  \
# 84                        en      Midnight in Paris   59436.0
# 85                        en            Match Point     116.0
# 86                        en             Annie Hall     703.0
# 87                        en             Annie Hall     703.0
# 94                        en           Gosford Park    5279.0
# ...                      ...                    ...       ...
# 4699                      en              High Noon     288.0
# 4700                      en  From Here to Eternity   11426.0
# 4701                      en  From Here to Eternity   11426.0
# 4707                      en                  Julia    7351.0
# 4708                      en                  Julia    7351.0
#
#      director_known_for_department movie_year    Year Winner  \
# 84                       Directing 2011-01-01  2011.0  False
# 85                       Directing 2005-01-01  2005.0  False
# 86                       Directing 1977-01-01  1977.0   True
# 87                       Directing 1977-01-01  1977.0  False
# 94                       Directing 2001-01-01  2001.0  False
# ...                            ...        ...     ...    ...
# 4699                     Directing 1952-01-01  1952.0  False
# 4700                     Directing 1953-01-01  1953.0   True
# 4701                     Directing 1953-01-01  1953.0   True
# 4707                       Writing 2008-01-01  1977.0  False
# 4708                       Writing 2008-01-01  1977.0  False
#
#                        Film         Nominee           Type
# 84        Midnight in Paris     Woody Allen  Academy Award
# 85              Match Point     Woody Allen   Golden Globe
# 86               Annie Hall     Woody Allen  Academy Award
# 87               Annie Hall     Woody Allen   Golden Globe
# 94             Gosford Park   Robert Altman  Academy Award
# ...                     ...             ...            ...
# 4699              High Noon  Fred Zinnemann  Academy Award
# 4700  From Here to Eternity  Fred Zinnemann  Academy Award
# 4701  From Here to Eternity  Fred Zinnemann   Golden Globe
# 4707                  Julia  Fred Zinnemann  Academy Award
# 4708                  Julia  Fred Zinnemann   Golden Globe
#
# [385 rows x 17 columns]

# %%
# Grouping directors who were in Awards DF
df_tmdb_awards_grouped = (df_tmdb_awards_nona.groupby(["director_name","Winner"]).agg({"director_popularity":"mean", "director_gender":"mean"}))
df_tmdb_awards_grouped.reset_index()
# Out:
#                    director_name  Winner  director_popularity  director_gender
# 0                    Adrian Lyne   False                0.600                2
# 1                 Akira Kurosawa   False                1.652                2
# 2                 Alan J. Pakula   False                1.452                2
# 3                    Alan Parker   False                1.400                2
# 4    Alejandro González Iñárritu   False                1.213                2
# ..                           ...     ...                  ...              ...
# 243                William Wyler   False                0.752                2
# 244                William Wyler    True                0.752                2
# 245                  Woody Allen   False                4.288                2
# 246                  Woody Allen    True                4.288                2
# 247             Édouard Molinaro   False                1.128                2
#
# [248 rows x 4 columns]

# %%
df_tmdb_awards_grouped.head(20)
# Out:
#                                     director_popularity  director_gender
# director_name               Winner
# Adrian Lyne                 False                 0.600                2
# Akira Kurosawa              False                 1.652                2
# Alan J. Pakula              False                 1.452                2
# Alan Parker                 False                 1.400                2
# Alejandro González Iñárritu False                 1.213                2
#                             True                  1.213                2
# Alexander Hall              False                 0.600                2
# Alexander Korda             False                 0.600                2
# Alexander Payne             False                 2.188                2
# Alfonso Cuarón              True                  2.042                2
# Alfred Hitchcock            False                 3.794                2
# Andrew Niccol               False                 1.400                2
# Ang Lee                     False                 3.237                2
#                             True                  3.237                2
# Anthony Harvey              False                 0.600                2
# Anthony Mann                False                 0.840                2
# Anthony Minghella           False                 1.428                2
# Arthur Hiller               False                 1.188                2
#                             True                  1.188                2
# Arthur Penn                 False                 1.400                2

# %%
df_tmdb_awards_grouped["director_popularity"].value_counts()
# Out:
# 0.600    57
# 1.400    13
# 0.980    11
# 0.840     7
# 1.380     5
#          ..
# 2.110     1
# 2.040     1
# 1.312     1
# 1.800     1
# 2.625     1
# Name: director_popularity, Length: 121, dtype: int64

# %%
df_tmdb["director_popularity"].value_counts()
# Out:
# 0.600    1909
# 0.980     331
# 1.400     225
# 1.380      99
# 0.840      90
#          ...
# 1.674       3
# 1.452       3
# 7.547       3
# 1.237       2
# 1.181       2
# Name: director_popularity, Length: 438, dtype: int64

# %%
# Doing analysis on director popularity based on gender and only on award winners or nominees

# %%
df_tmdb_awards_grouped_allwins = (df_tmdb_awards_grouped.groupby("director_gender").agg({"director_popularity":"mean"})).reset_index()

df_tmdb_awards_grouped_allwins
# Out:
#    director_gender  director_popularity
# 0                1             1.278857
# 1                2             1.633627

# %%
df_tmdb_awards_grouped_allwins = df_tmdb_awards_grouped_allwins.assign(director_gender=np.where(df_tmdb_awards_grouped_allwins["director_gender"]==2,"male","female"))
df_tmdb_awards_grouped_allwins = df_tmdb_awards_grouped_allwins.set_index("director_gender")

# %%
df_tmdb_awards_grouped_allwins.plot.bar();

# %%
#3. Checking the Merged director Genders

directors_genders_awards = pd.read_pickle("directors_genders_awards.pkl")
directors_genders_awards.reset_index()
# Out:
#         director_name  Year  director_gender  Winner
# 0         Adrian Lyne  1987                2       0
# 1      Akira Kurosawa  1985                2       0
# 2      Alan J. Pakula  1976                2       0
# 3         Alan Parker  1978                2       0
# 4         Alan Parker  1988                2       0
# ..                ...   ...              ...     ...
# 541       Woody Allen  1989                2       0
# 542       Woody Allen  1994                2       0
# 543       Woody Allen  2005                2       0
# 544       Woody Allen  2011                2       0
# 545  Édouard Molinaro  1979                2       0
#
# [546 rows x 4 columns]

# %%
# Checking Merge of Genders to Director Awards List
directors_genders_awards["director_gender"].value_counts()
# Out:
# 2    538
# 1      8
# Name: director_gender, dtype: int64

# %%
# Change Zeros to 2s
directors_genders_awards.loc[directors_genders_awards['director_gender'] == 0]=2

# %%
# Show DF

directors_genders_awards
# Out:
#                        director_gender  Winner
# director_name    Year
# Adrian Lyne      1987                2       0
# Akira Kurosawa   1985                2       0
# Alan J. Pakula   1976                2       0
# Alan Parker      1978                2       0
#                  1988                2       0
# ...                                ...     ...
# Woody Allen      1989                2       0
#                  1994                2       0
#                  2005                2       0
#                  2011                2       0
# Édouard Molinaro 1979                2       0
#
# [546 rows x 2 columns]

# %%
# Replace m and f
directors_genders_awards = directors_genders_awards.assign(director_gender=np.where(directors_genders_awards["director_gender"]==2,"male","female"))
directors_genders_awards
# Out:
#                       director_gender  Winner
# director_name    Year
# Adrian Lyne      1987            male       0
# Akira Kurosawa   1985            male       0
# Alan J. Pakula   1976            male       0
# Alan Parker      1978            male       0
#                  1988            male       0
# ...                               ...     ...
# Woody Allen      1989            male       0
#                  1994            male       0
#                  2005            male       0
#                  2011            male       0
# Édouard Molinaro 1979            male       0
#
# [546 rows x 2 columns]

# %%
directors_genders_awards.to_pickle("directors_genders_awards.pkl")

# %%
# Creating a movie DF with rating threshold

def movie_vote_amount(vote_count):
    df_movies = df_tmdb.loc[df_tmdb["movie_vote_count"] >= vote_count]
    return df_movies

df_movies = movie_vote_amount(20)
df_movies
# Out:
#          director_name director_gender director_id director_popularity  \
# 0        George Abbott            male        2004                 0.6
# 4         Jim Abrahams            male       12936               1.456
# 5         Jim Abrahams            male       12936               1.456
# 6         Jim Abrahams            male       12936               1.456
# 7          J.J. Abrams            male       15344               3.961
# ...                ...             ...         ...                 ...
# 5867      Edward Zwick            male        9181               1.863
# 5871  Andrzej Żuławski            male       32082                 0.6
# 5872  Andrzej Żuławski            male       32082                 0.6
# 5873  Andrzej Żuławski            male       32082                 0.6
# 5874   Xawery Żuławski            male     1138544                 0.6
#
#      movie_release_date  movie_vote_average  movie_vote_count  \
# 0            1957-08-29                 6.3              21.0
# 4            1980-07-02                 7.3            2453.0
# 5            1988-12-02                 7.2            2089.0
# 6            2006-04-12                 5.4            1955.0
# 7            2015-12-15                 7.4           14085.0
# ...                 ...                 ...               ...
# 5867         2016-10-19                 5.7            3097.0
# 5871         1981-05-27                 7.4             382.0
# 5872         1988-10-09                 8.3              46.0
# 5873         1975-02-12                 7.5              43.0
# 5874         2009-04-21                 5.7              30.0
#
#      movie_original_language                                     movie_title  \
# 0                         en                                 The Pajama Game
# 4                         en                                       Airplane!
# 5                         en  The Naked Gun: From the Files of Police Squad!
# 6                         en                                   Scary Movie 4
# 7                         en                    Star Wars: The Force Awakens
# ...                      ...                                             ...
# 5867                      en                     Jack Reacher: Never Go Back
# 5871                      fr                                      Possession
# 5872                      pl                             On the Silver Globe
# 5873                      fr                 That Most Important Thing: Love
# 5874                      pl                      Snow White and Russian Red
#
#       movie_id director_known_for_department movie_year
# 0      40867.0                     Directing 1957-01-01
# 4        813.0                       Writing 1980-01-01
# 5      37136.0                       Writing 1988-01-01
# 6       4257.0                       Writing 2006-01-01
# 7     140607.0                     Directing 2015-01-01
# ...        ...                           ...        ...
# 5867  343611.0                     Directing 2016-01-01
# 5871   21484.0                       Writing 1981-01-01
# 5872   27072.0                       Writing 1988-01-01
# 5873    3476.0                       Writing 1975-01-01
# 5874   36415.0                     Directing 2009-01-01
#
# [3418 rows x 12 columns]

# %%
df_movies_excel = df_movies.groupby(["movie_year","director_gender"]).agg({"movie_vote_average":"mean","director_gender":"count"})
df_movies_excel
# Out:
#                             movie_vote_average  director_gender
# movie_year director_gender
# 1887-01-01 male                       5.100000                1
# 1888-01-01 male                       6.400000                2
# 1896-01-01 female                     5.200000                1
# 1898-01-01 male                       6.900000                1
# 1902-01-01 male                       8.000000                1
# ...                                        ...              ...
# 2018-01-01 female                     6.120000                5
#            male                       6.792308               39
# 2019-01-01 female                     7.100000                2
#            male                       6.792857               14
# 2020-01-01 male                       6.000000                1
#
# [157 rows x 2 columns]

# %%
df_movies_excel.to_csv("df_movies_excel.csv")
