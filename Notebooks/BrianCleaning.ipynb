# %%
import requests
import pandas as pd
import numpy as np
import json
import matplotlib
from pandas import json_normalize

df_clean = pd.read_pickle("df_clean.pkl")

# %%
df_clean
# Out:
#          director_name director_gender director_id director_popularity  \
# 0       Dodo Abashidze               2      560142               0.728
# 1       Dodo Abashidze               2      560142               0.728
# 2       Dodo Abashidze               2      560142               0.728
# 3        George Abbott               2        2004                 0.6
# 4        George Abbott               2        2004                 0.6
# ...                ...             ...         ...                 ...
# 9239  Andrzej Żuławski               2       32082                 0.6
# 9240  Andrzej Żuławski               2       32082                 0.6
# 9241   Xawery Żuławski               2     1138544                 0.6
# 9242   Xawery Żuławski               2     1138544                 0.6
# 9243   Xawery Żuławski               2     1138544                 0.6
#
#      movie_release_date  movie_vote_average  movie_vote_count  \
# 0            1985-12-01                 7.1              14.0
# 1            1968-12-22                 5.8              12.0
# 2            1969-12-28                 6.1              11.0
# 3            1957-08-29                 6.3              21.0
# 4            1958-07-23                 6.9              17.0
# ...                 ...                 ...               ...
# 9239         1988-10-09                 8.3              46.0
# 9240         1975-02-12                 7.5              43.0
# 9241         2009-04-21                 5.7              30.0
# 9242                NaN                 8.0               7.0
# 9243         2006-07-22                 5.3               3.0
#
#      movie_original_language                      movie_title  movie_id
# 0                         ka     The Legend of Suram Fortress  103590.0
# 1                         ka                    Don't Grieve!   27922.0
# 2                         ka                        Pirosmani   88302.0
# 3                         en                  The Pajama Game   40867.0
# 4                         en                    Damn Yankees!   41253.0
# ...                      ...                              ...       ...
# 9239                      pl              On the Silver Globe   27072.0
# 9240                      fr  That Most Important Thing: Love    3476.0
# 9241                      pl       Snow White and Russian Red   36415.0
# 9242                      pl                              NaN   37337.0
# 9243                      pl                            Chaos  155675.0
#
# [9244 rows x 10 columns]

# %%
# Cleaning multiple listed names

df_clean2 = df_clean[df_clean['director_name'].map(df_clean['director_name'].value_counts()) > 3]
df_clean2
# Out:
#           director_name director_gender director_id director_popularity  \
# 42    Alejandro Agresti               2       21031                 0.6
# 43    Alejandro Agresti               2       21031                 0.6
# 44    Alejandro Agresti               2       21031                 0.6
# 45    Alejandro Agresti               0     1534477                 0.6
# 75       Robert Aldrich               2       18392                 0.6
# ...                 ...             ...         ...                 ...
# 9196         Yuan Zhang               1     2177982                 0.6
# 9197         Yuan Zhang               0       27075                 0.6
# 9198         Yuan Zhang               0     1997529                 0.6
# 9199         Yuan Zhang               0     2121542                 0.6
# 9200         Yuan Zhang               0     2121542                 0.6
#
#      movie_release_date  movie_vote_average  movie_vote_count  \
# 42           2006-06-16                 6.8            1619.0
# 43           2003-03-12                 7.0              32.0
# 44           2013-10-03                 4.1               9.0
# 45           1989-08-18                 6.3               3.0
# 75           1967-06-15                 7.7             606.0
# ...                 ...                 ...               ...
# 9196         1983-11-01                 0.0               0.0
# 9197         2006-09-21                 7.5              17.0
# 9198         2002-01-01                 0.0               0.0
# 9199         2015-05-29                 0.0               0.0
# 9200         2019-10-29                 0.0               0.0
#
#      movie_original_language             movie_title  movie_id
# 42                        en          The Lake House    2044.0
# 43                        es                Valentin   30125.0
# 44                        en        We're No Animals  289561.0
# 45                        es          Secret Wedding  367849.0
# 75                        en         The Dirty Dozen    1654.0
# ...                      ...                     ...       ...
# 9196                      zh                 Ward 16  593482.0
# 9197                      zh         Tuya's Marriage    2694.0
# 9198                      en  Roses Sing on New Snow  511507.0
# 9199                      zh              The Grow 2  546453.0
# 9200                      zh          Boundless Love  657998.0
#
# [2264 rows x 10 columns]

# %%
df_clean.loc[df_clean['director_gender'] == 0]
# Out:
#             director_name director_gender director_id director_popularity  \
# 6     George Abbott Clark               0     1811971                 0.6
# 28           Carine Adler               0      536511                 0.6
# 29           Carine Adler               0      536511                 0.6
# 45      Alejandro Agresti               0     1534477                 0.6
# 46            Aqeel Ahmed               0     2248194                 0.6
# ...                   ...             ...         ...                 ...
# 9221     Lydia Zimmermann               0      585942                 0.6
# 9222     Lydia Zimmermann               0      585942                 0.6
# 9235        Terry Zwigoff               0       17447               1.094
# 9236        Terry Zwigoff               0       17447               1.094
# 9237        Terry Zwigoff               0       17447               1.094
#
#      movie_release_date  movie_vote_average  movie_vote_count  \
# 6            2017-05-02                 4.9              84.0
# 28           1997-11-28                 7.0              16.0
# 29           1994-12-31                 5.0               1.0
# 45           1989-08-18                 6.3               3.0
# 46           2005-12-08                 5.0               2.0
# ...                 ...                 ...               ...
# 9221         2002-11-08                 5.7               3.0
# 9222         2016-09-23                 7.0               1.0
# 9235         2003-11-26                 6.5            1301.0
# 9236         2001-07-20                 7.3             798.0
# 9237         1994-09-10                 7.8             132.0
#
#      movie_original_language                            movie_title  movie_id
# 6                         en                      The Shadow Effect  383538.0
# 28                        en                         Under the Skin   77955.0
# 29                        en                                  Fever  140088.0
# 45                        es                         Secret Wedding  367849.0
# 46                        ur                 Shah Rukh Khan Ki Maut  584150.0
# ...                      ...                                    ...       ...
# 9221                      es  Aro Tolbukhin in the Mind of a Killer  222560.0
# 9222                      en                        Maria converses  417916.0
# 9235                      en                              Bad Santa   10147.0
# 9236                      en                            Ghost World    1548.0
# 9237                      en                                  Crumb   26564.0
#
# [2683 rows x 10 columns]

# %%
# Create function DF "df_movies" based on a minimum vote amount

def movie_vote_amount(vote_count):
    df_movies = df_clean.loc[df_clean["movie_vote_count"] >= vote_count]
    return df_movies

movie_vote_amount(10)
# Out:
#          director_name director_gender director_id director_popularity  \
# 0       Dodo Abashidze               2      560142               0.728
# 1       Dodo Abashidze               2      560142               0.728
# 2       Dodo Abashidze               2      560142               0.728
# 3        George Abbott               2        2004                 0.6
# 4        George Abbott               2        2004                 0.6
# ...                ...             ...         ...                 ...
# 9237     Terry Zwigoff               0       17447               1.094
# 9238  Andrzej Żuławski               2       32082                 0.6
# 9239  Andrzej Żuławski               2       32082                 0.6
# 9240  Andrzej Żuławski               2       32082                 0.6
# 9241   Xawery Żuławski               2     1138544                 0.6
#
#      movie_release_date  movie_vote_average  movie_vote_count  \
# 0            1985-12-01                 7.1              14.0
# 1            1968-12-22                 5.8              12.0
# 2            1969-12-28                 6.1              11.0
# 3            1957-08-29                 6.3              21.0
# 4            1958-07-23                 6.9              17.0
# ...                 ...                 ...               ...
# 9237         1994-09-10                 7.8             132.0
# 9238         1981-05-27                 7.4             382.0
# 9239         1988-10-09                 8.3              46.0
# 9240         1975-02-12                 7.5              43.0
# 9241         2009-04-21                 5.7              30.0
#
#      movie_original_language                      movie_title  movie_id
# 0                         ka     The Legend of Suram Fortress  103590.0
# 1                         ka                    Don't Grieve!   27922.0
# 2                         ka                        Pirosmani   88302.0
# 3                         en                  The Pajama Game   40867.0
# 4                         en                    Damn Yankees!   41253.0
# ...                      ...                              ...       ...
# 9237                      en                            Crumb   26564.0
# 9238                      fr                       Possession   21484.0
# 9239                      pl              On the Silver Globe   27072.0
# 9240                      fr  That Most Important Thing: Love    3476.0
# 9241                      pl       Snow White and Russian Red   36415.0
#
# [6361 rows x 10 columns]

# %%
# Joining AwardDF to Df_Clean
directors_all = pd.read_pickle("directors_all.pkl")
directors_all
# Out:
#      Year  Winner                             Film            Nominee  \
# 0    1928    True              Two Arabian Knights    Lewis Milestone
# 1    1928   False                           Speedy          Ted Wilde
# 2    1928    True                       7th Heaven      Frank Borzage
# 3    1928   False                  Sorrell and Son     Herbert Brenon
# 4    1928   False                        The Crowd         King Vidor
# ..    ...     ...                              ...                ...
# 807  2019    True                             1917         Sam Mendes
# 808  2019   False                         Parasite       Bong Joon Ho
# 809  2019   False                            Joker      Todd Phillips
# 810  2019   False                    Irishman, The    Martin Scorsese
# 811  2019   False  Once Upon a Time...in Hollywood  Quentin Tarantino
#
#               Type
# 0    Academy Award
# 1    Academy Award
# 2    Academy Award
# 3    Academy Award
# 4    Academy Award
# ..             ...
# 807   Golden Globe
# 808   Golden Globe
# 809   Golden Globe
# 810   Golden Globe
# 811   Golden Globe
#
# [812 rows x 5 columns]

# %%
# Changing nominee name to "director_name"
directors_all.rename(columns={'Nominee':'director_name'}, inplace=True)
directors_all
# Out:
#      Year  Winner                             Film      director_name  \
# 0    1928    True              Two Arabian Knights    Lewis Milestone
# 1    1928   False                           Speedy          Ted Wilde
# 2    1928    True                       7th Heaven      Frank Borzage
# 3    1928   False                  Sorrell and Son     Herbert Brenon
# 4    1928   False                        The Crowd         King Vidor
# ..    ...     ...                              ...                ...
# 807  2019    True                             1917         Sam Mendes
# 808  2019   False                         Parasite       Bong Joon Ho
# 809  2019   False                            Joker      Todd Phillips
# 810  2019   False                    Irishman, The    Martin Scorsese
# 811  2019   False  Once Upon a Time...in Hollywood  Quentin Tarantino
#
#               Type
# 0    Academy Award
# 1    Academy Award
# 2    Academy Award
# 3    Academy Award
# 4    Academy Award
# ..             ...
# 807   Golden Globe
# 808   Golden Globe
# 809   Golden Globe
# 810   Golden Globe
# 811   Golden Globe
#
# [812 rows x 5 columns]

# %%
(directors_all["director_name"].str.replace(" ", "").str.replace("\t","").str.isalpha().value_counts())
#inbetween = directors_all["director_name"].str.replace(" ", "").isalpha()
#directors_all["Name"]= directors_all["Name"].str.replace(" ", "")
# Out:
# True     776
# False     36
# Name: director_name, dtype: int64

# %%
directors_all.loc[directors_all['director_name']]
directors_all2 = directors_all[directors_all['director_name'].map(directors_all['director_name']).str.isalpha() == False]
directors_all2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-80-907396c1113a> in <module>
# ----> 1 directors_all.loc[directors_all['director_name']]
#       2 directors_all2 = directors_all[directors_all['director_name'].map(directors_all['director_name']).str.isalpha() == False]
#       3 directors_all2
#
# ~\.conda\envs\backpack_banana\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# ~\.conda\envs\backpack_banana\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1952                     raise ValueError("Cannot index with multidimensional key")
#    1953
# -> 1954                 return self._getitem_iterable(key, axis=axis)
#    1955
#    1956             # nested tuple slicing
#
# ~\.conda\envs\backpack_banana\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1593         else:
#    1594             # A collection of keys
# -> 1595             keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1596             return self.obj._reindex_with_indexers(
#    1597                 {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# ~\.conda\envs\backpack_banana\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1551
#    1552         self._validate_read_indexer(
# -> 1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#    1555         return keyarr, indexer
#
# ~\.conda\envs\backpack_banana\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1638             if missing == len(indexer):
#    1639                 axis_name = self.obj._get_axis_name(axis)
# -> 1640                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1641
#    1642             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['Lewis Milestone', 'Ted Wilde', 'Frank Borzage', 'Herbert Brenon',\n       'King Vidor', 'Lionel Barrymore', 'Harry Beaumont', 'Irving Cummings',\n       'Frank Lloyd', 'Frank Lloyd',\n       ...\n       'Alfonso Cuarón', 'Bradley Cooper', 'Peter Farrelly', 'Spike Lee',\n       'Adam McKay', 'Sam Mendes', 'Bong Joon Ho', 'Todd Phillips',\n       'Martin Scorsese', 'Quentin Tarantino'],\n      dtype='object', length=812)] are in the [index]"

# %%
directors_all_gender = (directors_all.merge(right=df_clean, 
                                   how="left", 
                                   on="director_name").groupby("director_name").agg({"director_gender":"max"}))
directors_all_gender.loc[directors_all_gender["director_gender"].isna()==True]
# Out:
#                            director_gender
# director_name
# \tDamien Chazelle                      NaN
# Adam McKay                             NaN
# Adam McKay\t                           NaN
# Barry Jenkins                          NaN
# Barry Jenkins\t                        NaN
# ...                                    ...
# W. S. Van Dyke                         NaN
# W. S. Van Dyke                         NaN
# Warren Beatty, Buck Henry              NaN
# William Wellman                        NaN
# Yorgos Lanthimos\t                     NaN
#
# [71 rows x 1 columns]

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
def fuzzy_merge(df_1, df_2, key1, key2, threshold=90, limit=2):
    """
    df_1 is the left table to join
    df_2 is the right table to join
    key1 is the key column of the left table
    key2 is the key column of the right table
    threshold is how close the matches should be to return a match, based on Levenshtein distance
    limit is the amount of matches that will get returned, these are sorted high to low
    """
    s = df_2[key2].tolist()

    m = df_1[key1].apply(lambda x: process.extract(x, s, limit=limit))    
    df_1['matches'] = m

    m2 = df_1['matches'].apply(lambda x: ', '.join([i[0] for i in x if i[1] >= threshold]))
    df_1['matches'] = m2

    return df_1


directors_all_matched = fuzzy_merge(directors_all, df_clean, "director_name", "director_name", threshold=80)
# Out:
#      Year  Winner                             Film      director_name  \
# 0    1928    True              Two Arabian Knights    Lewis Milestone
# 1    1928   False                           Speedy          Ted Wilde
# 2    1928    True                       7th Heaven      Frank Borzage
# 3    1928   False                  Sorrell and Son     Herbert Brenon
# 4    1928   False                        The Crowd         King Vidor
# ..    ...     ...                              ...                ...
# 807  2019    True                             1917         Sam Mendes
# 808  2019   False                         Parasite       Bong Joon Ho
# 809  2019   False                            Joker      Todd Phillips
# 810  2019   False                    Irishman, The    Martin Scorsese
# 811  2019   False  Once Upon a Time...in Hollywood  Quentin Tarantino
#
#               Type                               matches
# 0    Academy Award      Lewis Milestone, Lewis Milestone
# 1    Academy Award
# 2    Academy Award          Frank Borzage, Frank Borzage
# 3    Academy Award        Herbert Brenon, Herbert Brenon
# 4    Academy Award                King Vidor, King Vidor
# ..             ...                                   ...
# 807   Golden Globe                Sam Mendes, Sam Mendes
# 808   Golden Globe            Bong Joon-ho, Bong Joon-ho
# 809   Golden Globe
# 810   Golden Globe      Martin Scorsese, Martin Scorsese
# 811   Golden Globe  Quentin Tarantino, Quentin Tarantino
#
# [812 rows x 6 columns]

# %%
directors_all_matched = fuzzy_merge(directors_all, df_clean, "director_name", "director_name", threshold=80)

# %%
director_names = (directors_all_matched["matches"].str.split(", ",n=1,expand=True).reset_index())
director_names
# Out:
#      index                  0                  1
# 0        0    Lewis Milestone    Lewis Milestone
# 1        1                                  None
# 2        2      Frank Borzage      Frank Borzage
# 3        3     Herbert Brenon     Herbert Brenon
# 4        4         King Vidor         King Vidor
# ..     ...                ...                ...
# 807    807         Sam Mendes         Sam Mendes
# 808    808       Bong Joon-ho       Bong Joon-ho
# 809    809                                  None
# 810    810    Martin Scorsese    Martin Scorsese
# 811    811  Quentin Tarantino  Quentin Tarantino
#
# [812 rows x 3 columns]

# %%
directors_all_matched = directors_all_matched.assign(TMDBnames=director_names[1])

# %%
directors_all_matched = directors_all_matched.rename(columns={"director_name":"name","TMDBnames":"director_name"})
directors_all_matched
# Out:
#      Year  Winner                             Film               name  \
# 0    1928    True              Two Arabian Knights    Lewis Milestone
# 1    1928   False                           Speedy          Ted Wilde
# 2    1928    True                       7th Heaven      Frank Borzage
# 3    1928   False                  Sorrell and Son     Herbert Brenon
# 4    1928   False                        The Crowd         King Vidor
# ..    ...     ...                              ...                ...
# 807  2019    True                             1917         Sam Mendes
# 808  2019   False                         Parasite       Bong Joon Ho
# 809  2019   False                            Joker      Todd Phillips
# 810  2019   False                    Irishman, The    Martin Scorsese
# 811  2019   False  Once Upon a Time...in Hollywood  Quentin Tarantino
#
#               Type                               matches               name
# 0    Academy Award      Lewis Milestone, Lewis Milestone    Lewis Milestone
# 1    Academy Award                                                     None
# 2    Academy Award          Frank Borzage, Frank Borzage      Frank Borzage
# 3    Academy Award        Herbert Brenon, Herbert Brenon     Herbert Brenon
# 4    Academy Award                King Vidor, King Vidor         King Vidor
# ..             ...                                   ...                ...
# 807   Golden Globe                Sam Mendes, Sam Mendes         Sam Mendes
# 808   Golden Globe            Bong Joon-ho, Bong Joon-ho       Bong Joon-ho
# 809   Golden Globe                                                     None
# 810   Golden Globe      Martin Scorsese, Martin Scorsese    Martin Scorsese
# 811   Golden Globe  Quentin Tarantino, Quentin Tarantino  Quentin Tarantino
#
# [812 rows x 7 columns]

# %%
directors_all_matched = directors_all_matched.rename(columns={directors_all_matched.columns[6]:"director_name"})
directors_all_matched
# Out:
#      Year  Winner                             Film      director_name  \
# 0    1928    True              Two Arabian Knights    Lewis Milestone
# 1    1928   False                           Speedy          Ted Wilde
# 2    1928    True                       7th Heaven      Frank Borzage
# 3    1928   False                  Sorrell and Son     Herbert Brenon
# 4    1928   False                        The Crowd         King Vidor
# ..    ...     ...                              ...                ...
# 807  2019    True                             1917         Sam Mendes
# 808  2019   False                         Parasite       Bong Joon Ho
# 809  2019   False                            Joker      Todd Phillips
# 810  2019   False                    Irishman, The    Martin Scorsese
# 811  2019   False  Once Upon a Time...in Hollywood  Quentin Tarantino
#
#               Type                               matches      director_name
# 0    Academy Award      Lewis Milestone, Lewis Milestone    Lewis Milestone
# 1    Academy Award                                                     None
# 2    Academy Award          Frank Borzage, Frank Borzage      Frank Borzage
# 3    Academy Award        Herbert Brenon, Herbert Brenon     Herbert Brenon
# 4    Academy Award                King Vidor, King Vidor         King Vidor
# ..             ...                                   ...                ...
# 807   Golden Globe                Sam Mendes, Sam Mendes         Sam Mendes
# 808   Golden Globe            Bong Joon-ho, Bong Joon-ho       Bong Joon-ho
# 809   Golden Globe                                                     None
# 810   Golden Globe      Martin Scorsese, Martin Scorsese    Martin Scorsese
# 811   Golden Globe  Quentin Tarantino, Quentin Tarantino  Quentin Tarantino
#
# [812 rows x 7 columns]

# %%
directors_all_matched.columns = ["Year","Winner","Film","Name","Type","matches","director_name"]
directors_all_matched
# Out:
#      Year  Winner                             Film               Name  \
# 0    1928    True              Two Arabian Knights    Lewis Milestone
# 1    1928   False                           Speedy          Ted Wilde
# 2    1928    True                       7th Heaven      Frank Borzage
# 3    1928   False                  Sorrell and Son     Herbert Brenon
# 4    1928   False                        The Crowd         King Vidor
# ..    ...     ...                              ...                ...
# 807  2019    True                             1917         Sam Mendes
# 808  2019   False                         Parasite       Bong Joon Ho
# 809  2019   False                            Joker      Todd Phillips
# 810  2019   False                    Irishman, The    Martin Scorsese
# 811  2019   False  Once Upon a Time...in Hollywood  Quentin Tarantino
#
#               Type                               matches      director_name
# 0    Academy Award      Lewis Milestone, Lewis Milestone    Lewis Milestone
# 1    Academy Award                                                     None
# 2    Academy Award          Frank Borzage, Frank Borzage      Frank Borzage
# 3    Academy Award        Herbert Brenon, Herbert Brenon     Herbert Brenon
# 4    Academy Award                King Vidor, King Vidor         King Vidor
# ..             ...                                   ...                ...
# 807   Golden Globe                Sam Mendes, Sam Mendes         Sam Mendes
# 808   Golden Globe            Bong Joon-ho, Bong Joon-ho       Bong Joon-ho
# 809   Golden Globe                                                     None
# 810   Golden Globe      Martin Scorsese, Martin Scorsese    Martin Scorsese
# 811   Golden Globe  Quentin Tarantino, Quentin Tarantino  Quentin Tarantino
#
# [812 rows x 7 columns]

# %%
directors_all_gender = (directors_all_matched.merge(right=df_clean, 
                                   how="left", 
                                   on="director_name").groupby(["director_name","Year"]).agg({"director_gender":"max","Winner":np.count_nonzero}))
directors_all_gender
# Out:
#                        director_gender  Winner
# director_name    Year
# Adrian Lyne      1987                2       0
# Akira Kurosawa   1985                2       0
# Alan J. Pakula   1976                2       0
# Alan Parker      1978                2       0
#                  1988                2       0
# ...                                ...     ...
# Woody Allen      1989                2       0
#                  1994                2       0
#                  2005                2       0
#                  2011                2       0
# Édouard Molinaro 1979                2       0
#
# [546 rows x 2 columns]

# %%
directors_all_gender.to_pickle("directors_genders_awards.pkl")

# %%
directors_genders_awards = pd.read_pickle("directors_genders_awards.pkl")
directors_genders_awards

# %%
directors_all_matched.to_pickle("directors_all_matched.pkl")

# %%
# Getting new pickle with better results
df_all = pd.read_pickle("df_all2.pkl")
df_all
# Out:
#      movie_release_date  movie_id  movie_vote_count movie_video  \
# 0            1985-12-01  103590.0              14.0       False
# 1            1968-12-22   27922.0              12.0       False
# 2            1969-12-28   88302.0              11.0       False
# 3            1957-08-29   40867.0              21.0       False
# 4            1958-07-23   41253.0              17.0       False
# ...                 ...       ...               ...         ...
# 9198         1988-10-09   27072.0              46.0       False
# 9199         1975-02-12    3476.0              43.0       False
# 9200         2009-04-21   36415.0              30.0       False
# 9201                NaN   37337.0               7.0         NaN
# 9202         2006-07-22  155675.0               3.0       False
#
#      movie_media_type  movie_vote_average                      movie_title  \
# 0               movie                 7.1     The Legend of Suram Fortress
# 1               movie                 5.8                    Don't Grieve!
# 2               movie                 6.1                        Pirosmani
# 3               movie                 6.3                  The Pajama Game
# 4               movie                 6.9                    Damn Yankees!
# ...               ...                 ...                              ...
# 9198            movie                 8.3              On the Silver Globe
# 9199            movie                 7.5  That Most Important Thing: Love
# 9200            movie                 5.7       Snow White and Russian Red
# 9201               tv                 8.0                              NaN
# 9202            movie                 5.3                            Chaos
#
#         movie_genre_ids       movie_original_title movie_original_language  \
# 0              [18, 14]      ამბავი სურამის ციხისა                      ka
# 1       [35, 18, 10749]                  Не горюй!                      ka
# 2                  [18]                  ფიროსმანი                      ka
# 3           [35, 10402]            The Pajama Game                      en
# 4       [35, 14, 10402]              Damn Yankees!                      en
# ...                 ...                        ...                     ...
# 9198  [12, 18, 14, 878]         Na srebrnym globie                      pl
# 9199        [18, 10749]  L'important c'est d'aimer                      fr
# 9200               [18]         Wojna polsko-ruska                      pl
# 9201        [18, 10759]                        NaN                      pl
# 9202               [18]                      Chaos                      pl
#
#       ...                 movie_poster_path     director_name director_gender  \
# 0     ...  /k0ykSBVFXlKi938NvUUoGOkCA2t.jpg    Dodo Abashidze               2
# 1     ...  /ibnDSdqaqvMJKvfOjozh9C6iL9w.jpg    Dodo Abashidze               2
# 2     ...  /dsRYQQEcI4fdnoknzuLa1xaGKib.jpg    Dodo Abashidze               2
# 3     ...  /lsd5GXaDYy1A8TOg85rfZpZs4Q9.jpg     George Abbott               2
# 4     ...  /c1EFAgqAInkbhBFvROmBP4BDdfa.jpg     George Abbott               2
# ...   ...                               ...               ...             ...
# 9198  ...  /nOCbv7AZicEZQS6pddihVPJATfZ.jpg  Andrzej Żuławski               2
# 9199  ...    /NR9X3F4aCqvoYRx8h4pG30zVe.jpg  Andrzej Żuławski               2
# 9200  ...  /2uMsnWscxHQii4N4bept7sfMQ6c.jpg   Xawery Żuławski               2
# 9201  ...  /vU0kLyAfdqynoYicwGuqXNkFewR.jpg   Xawery Żuławski               2
# 9202  ...                              None   Xawery Żuławski               2
#
#      director_known_for_department director_popularity director_id  \
# 0                           Acting               0.728      560142
# 1                           Acting               0.728      560142
# 2                           Acting               0.728      560142
# 3                        Directing                 0.6        2004
# 4                        Directing                 0.6        2004
# ...                            ...                 ...         ...
# 9198                       Writing                 0.6       32082
# 9199                       Writing                 0.6       32082
# 9200                     Directing                 0.6     1138544
# 9201                     Directing                 0.6     1138544
# 9202                     Directing                 0.6     1138544
#
#      movie_original_name movie_name movie_origin_country movie_first_air_date
# 0                    NaN        NaN                  NaN                  NaN
# 1                    NaN        NaN                  NaN                  NaN
# 2                    NaN        NaN                  NaN                  NaN
# 3                    NaN        NaN                  NaN                  NaN
# 4                    NaN        NaN                  NaN                  NaN
# ...                  ...        ...                  ...                  ...
# 9198                 NaN        NaN                  NaN                  NaN
# 9199                 NaN        NaN                  NaN                  NaN
# 9200                 NaN        NaN                  NaN                  NaN
# 9201             Pitbull    Pitbull                 [PL]           2005-12-15
# 9202                 NaN        NaN                  NaN                  NaN
#
# [9203 rows x 23 columns]

# %%
df_all.loc[df_all["director_name"].str.contains("Van Dyke")]
# Out:
#      movie_release_date  movie_id  movie_vote_count movie_video  \
# 8417         1915-02-08     618.0             267.0       False
# 8418         1934-05-25    3529.0             207.0       False
# 8419         1916-09-04    3059.0             153.0       False
#
#      movie_media_type  movie_vote_average  \
# 8417            movie                 6.3
# 8418            movie                 7.6
# 8419            movie                 7.5
#
#                                            movie_title  movie_genre_ids  \
# 8417                             The Birth of a Nation  [18, 36, 10752]
# 8418                                      The Thin Man   [35, 80, 9648]
# 8419  Intolerance: Love's Struggle Throughout the Ages         [18, 36]
#
#                                   movie_original_title  \
# 8417                             The Birth of a Nation
# 8418                                      The Thin Man
# 8419  Intolerance: Love's Struggle Throughout the Ages
#
#      movie_original_language  ...  \
# 8417                      en  ...
# 8418                      en  ...
# 8419                      en  ...
#
#                                          movie_overview  \
# 8417  Two families, abolitionist Northerners the Sto...
# 8418  A husband-and-wife detective team takes on the...
# 8419  The story of a poor young woman, separated by ...
#
#                      movie_poster_path  director_name director_gender  \
# 8417  /pNpOXpQI5GSUfiWypubYtMh9928.jpg  W.S. Van Dyke               2
# 8418  /kVYDx3jOGS4Hbs3ykvewHmwAw9B.jpg  W.S. Van Dyke               2
# 8419  /mnjifw19X094HvG80CN7nyMSRsD.jpg  W.S. Van Dyke               2
#
#      director_popularity director_id movie_original_name movie_name  \
# 8417               0.716       32427                 NaN        NaN
# 8418               0.716       32427                 NaN        NaN
# 8419               0.716       32427                 NaN        NaN
#
#      movie_origin_country movie_first_air_date
# 8417                  NaN                  NaN
# 8418                  NaN                  NaN
# 8419                  NaN                  NaN
#
# [3 rows x 22 columns]

# %%
df_clean2 = pd.read_pickle("df_clean2.pkl")
df_clean2["director_known_for_department"]=="Directing"
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 9198    False
# 9199    False
# 9200     True
# 9201     True
# 9202     True
# Name: director_known_for_department, Length: 9203, dtype: bool
